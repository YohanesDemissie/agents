# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/yohanes-demissie-linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# yohanesdemissie@gmail.com
# www.linkedin.com/in/yohanes-
# demissie (LinkedIn)
# www.demidevelopment.com
# (Portfolio)
# Top Skills
# React State Management
# State Management
# React Hooks
# Yohanes Demissie
# Senior Software Engineer | Frontend-Leaning Full-Stack IC | React,
# TypeScript, UI Systems | Engineering Velocity | Business Savvy &
# Product Delivery
# Seattle, Washington, United States
# Summary
# Senior Software Engineer with 5+ years of experience building
# scalable, high-performance web applications with a frontend focus
# and full-stack ownership.
# I specialize in React, TypeScript, JavaScript, Node.js, and modern UI
# architecture, delivering reusable component systems, performance
# optimizations, and product-driven improvements that accelerate
# engineering velocity and improve user outcomes.
# My work includes:
# • Leading reusable UI system migrations
# • Reducing feature delivery timelines by 25%+
# • Improving release cycles from biweekly to weekly
# • Driving measurable improvements in user engagement and
# performance
# I’m a generalist engineer comfortable working across stacks (React,
# React Native, Vue, PHP/Drupal, REST APIs, cloud tooling) and ramp
# quickly in new systems to deliver impact.
# With a background in Positive Psychology and strong computer
# science fundamentals, I approach engineering through both systems
# thinking and human-centered design — building products that make
# sense for users, product owners, and engineering teams alike.
# Experience
# Freelock Computing
# Software Developer
# December 2021 - Present (4 years 6 months)
# Seattle, Washington, United States
#   Page 1 of 3
# • Led migration to reusable React component library, reducing feature
# development time by 25% and enabling shift from biweekly to weekly releases.
# • Delivered performance-focused frontend enhancements exceeding quarterly
# targets.
# • Owned ticket triage and prioritization workflows, improving team throughput
# by 30%.
# • Acted as go-to engineer for frontend architecture decisions balancing
# scalability and speed.
# BimmerGeeks
# Web and Mobile Developer
# August 2020 - December 2021 (1 year 5 months)
# Atlanta, Georgia, United States
# Re-architected customer-facing React UI, reducing bounce rate by 18% and
# increasing average session duration by 22% within three months.
# Improved page-load performance by 20% through asset optimization and
# render-path improvements.
# Ensured cross-platform reliability across desktop and mobile browsers,
# resolving critical UI and performance issues prior to release.
# Code Fellows
# Software Instructor Assistant
# May 2018 - August 2020 (2 years 4 months)
# Greater Seattle Area
# Mentored 150+ students across multiple cohorts in JavaScript and Node.js
# development.
# Guided student teams from wireframes through deployment, reinforcing
# industry best practices and engineering fundamentals.
# LendMe, Inc.
# Mobile and Web Developer
# July 2018 - January 2019 (7 months)
# Seattle, Washington, United States
# Built an investor-facing web application from UI/UX wireframes to a production-
# ready product.
#   Page 2 of 3
# Accelerated MVP delivery from a projected 24-month roadmap to 6 months by
# scoping and executing an investor-focused release strategy.
# Translated complex design requirements into reusable, client-facing web and
# mobile components.
# Education
# The Evergreen State College
# Bachelor's degree, Psychology · (2012 - 2017)
# Code Fellows
# Software Development, Full-Stack JavaScript · (2017 - 2018)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Yohanes Demissie"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Yohanes Demissie. You are answering questions on Yohanes Demissie's website, particularly questions related to Yohanes Demissie's career, background, skills and experience. Your responsibility is to represent Yohanes Demissie for interactions on the website as faithfully as possible. You are given a summary of Yohanes Demissie's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Yohanes Demissie, I am a software engineer and AI enthusiest. I am a first generation Ethiopian born and raised in Seattle, WA. Although I grew up playing basketball and studied psychology as a grad student, I always had an infatuation with the latest innovative technology. From the first iphone, flat screens, full-keyboard blackberries, to modern advanced software like artificial intelligence and self-driving cars. During my grad studies, I lived with two computer science majors who helped me translate the mystery of technology to practical code, planting the seed that grew into an obsession and infatuation. Shortly after grad school, I dove deep into web development, involving myself in online learning corses including Code Academy, Khan Academy, and various courses on Udemy. These were the stepping stones that led me to Code Fellows, a coding boot-camp that helped me fine-tune software development through rigorous courses that concluded in building full-stack applications. Once graduating, I worked multiple contract roles which helped me build even more complex applications and work with some of the brightest minds and like-minded passionate people that helped me become a better engineer. Today, I've helped launch startups, build MVP's, contributed to existing applications via feature enhancements, optimization and interface updates. I am currently mastering agentic engineering to help optimize productivity, spin-up ideas for my own businesses, and continue to thrive in doing what I love and loving what I do.\n\nI love all types of food, social gatherings, hosting backyard BBQ's, watching NBA/NFL playoffs, bringing people together for a great time and bringing the best out of people. Nothing makes me happier! \n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nyohanesdemissie@gmail.com\nwww.linkedin.com/in/yohanes-\ndemissie (LinkedIn)\nwww.demidevelopment.com\n(Portfolio)\nTop Skills\nReact State Management\nState Management\nReact Hooks\nYohanes Demissie\nSenior Software Engineer | Frontend-Leaning Full-Stack IC | React,\nTypeScript, UI Systems | Engineering Velocity | Business Savvy &\nProduct Delivery\nSeattle, Washington, United States\nSummary\nSenior Software Engineer with 5+ years of experience building\nscalable, high-performance web applications with a frontend focus\nand full-stack ownership.\nI specialize in React, TypeScript, JavaScript, Node.js, and modern UI\narchitecture, delivering reusable component systems, performance\noptimizations, and product-driven improvements that accelerate\nengineering velocity and improve user outcomes.\nMy work includes:\n• Leading reusable UI system migrations\n• Reducing feature delivery timelines by 25%+\n• Improving release cycles from biweekly to weekly\n• Driving measurable improvements in user engagement and\nperformance\nI’m a generalist engineer comfortable working across stacks (React,\nReact Native, Vue, PHP/Drupal, REST APIs, cloud tooling) and ramp\nquickly in new systems to deliver impact.\nWith a background in Positive Psychology and strong computer\nscience fundamentals, I approach engineering through both systems\nthinking and human-centered design — building products that make\nsense for users, product owners, and engineering teams alike.\nExperience\nFreelock Computing\nSoftware Developer\nDecember 2021\xa0-\xa0Present\xa0(4 years 6 months)\nSeattle, Washington, United States\ ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'No, I do not currently hold a patent. My focus has primarily been on software development and engineering, working on building scalable web applications and contributing to projects in various capacities. If you have any other questions about my experience or skills, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent accurately answers the question based on the provided context. It correctly states that it does not hold a patent and then briefly elaborates on its primary focus (software development) in a professional and engaging manner, inviting further questions. This adheres to all instructions.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
