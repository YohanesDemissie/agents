# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    # model="gpt-4.1-nano",
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If it takes five machines five minutes to make five widgets, how long would it take 100 machines to make 100 widgets?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# - It takes **5 machines** 5 minutes to make **5 widgets**.
# - This means that each machine makes 1 widget in 5 minutes because 5 machines make 5 widgets in 5 minutes.
#
# So:
# - The rate of one machine is 1 widget per 5 minutes.
#
# Now, we are asked:
# - How long would it take for **100 machines** to make **100 widgets**?
#
# Since each machine makes 1 widget in 5 minutes, and we have 100 machines working in parallel, each making 1 widget, the 100 machines can make 100 widgets in **5 minutes**.
#
# **Answer: 5 minutes**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# - It takes **5 machines** 5 minutes to make **5 widgets**.
# - This means that each machine makes 1 widget in 5 minutes because 5 machines make 5 widgets in 5 minutes.
#
# So:
# - The rate of one machine is 1 widget per 5 minutes.
#
# Now, we are asked:
# - How long would it take for **100 machines** to make **100 widgets**?
#
# Since each machine makes 1 widget in 5 minutes, and we have 100 machines working in parallel, each making 1 widget, the 100 machines can make 100 widgets in **5 minutes**.
#
# **Answer: 5 minutes**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:
messages = [{"role": "user", "content": "pick a business area that might be worth exploring for an agentic ai opportunity."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": "present a pain point in the business idea."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

pain_point = response.choices[0].message.content

print(pain_point)

messages = [{"role": "user", "content": "propose an agentic ai solution to the pain point."}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content

print(answer)
# Out:
# One promising business area to explore for an agentic AI opportunity is **personalized healthcare**.
#
# ### Rationale:
#
# 1. **Data Utilization**: The healthcare sector generates vast amounts of data from various sources, including electronic health records, genetic testing, wearables, and patient interactions. Agentic AI can analyze this data to provide tailored treatment plans and health recommendations for individuals.
#
# 2. **Precision Medicine**: With the rise of genomics and individualized treatment plans, AI can help in identifying the best therapeutic approaches based on a patient’s genetic makeup and lifestyle factors. This could lead to improved patient outcomes and reduced trial-and-error prescribing.
#
# 3. **Patient Monitoring and Support**: Agentic AI can enhance remote patient monitoring systems, proactively engaging with patients to manage chronic diseases. It can analyze real-time data from wearables to alert healthcare providers and patients about potential health risks, enabling timely interventions.
#
# 4. **Mental Health Support**: AI-driven chatbots and mental health tools can offer personalized support and therapy recommendations. They can analyze user interactions and feedback to adapt their support strategies effectively.
#
# 5. **Operational Efficiency**: Beyond direct patient care, AI can streamline administrative processes within healthcare settings, such as optimizing scheduling, managing patient flow, and enhancing resource allocation, ultimately leading to cost savings and improved care delivery.
#
# 6. **Regulatory Compliance**: While navigating the complex regulatory landscape in healthcare is challenging, an AI system designed to ensure compliance with regulations (like HIPAA in the U.S.) and manage risks could be a significant value addition for healthcare organizations.
#
# ### Potential Applications:
#
# - An AI-powered platform that provides personalized health advice and medication reminders based on an individual’s health data.
# - A virtual health assistant that helps patients understand their conditions and manages appointments or follow-ups.
# - A predictive analytics tool for healthcare providers that identifies patients at risk for certain conditions based on their historical data.
#
# Overall, the intersection of AI and personalized healthcare presents numerous opportunities for innovation, improved patient outcomes, and efficiency in healthcare delivery.
# Certainly! To provide a relevant pain point, could you please share a brief description of the business idea?
# To effectively propose an agentic AI solution, we first need to clearly identify a specific pain point. For this example, let's consider a common pain point in the logistics and supply chain industry: **inefficient inventory management**.
#
# ### Pain Point: Inefficient Inventory Management
# Many businesses struggle with maintaining optimal inventory levels, which can lead to overstock, stockouts, increased storage costs, and ultimately lost sales.
#
# ### Solution: Agentic AI-Powered Inventory Optimization System
#
# #### Overview:
# The proposed solution is an agentic AI system that autonomously manages inventory by predicting demand, optimizing stock levels, and automating reordering processes. This system employs machine learning algorithms, IoT sensors, and real-time data processing to enhance decision-making.
#
# #### Components of the Solution:
#
# 1. **Demand Forecasting:**
#    - **AI Algorithms:** Leverage machine learning models that analyze historical sales data, market trends, and external factors (seasonality, holidays, promotions) to accurately predict future demand for each product.
#    - **Continuous Learning:** The algorithms continually learn from new data inputs, ensuring forecasts remain accurate and adjusting for any anomalies.
#
# 2. **Real-Time Inventory Monitoring:**
#    - **IoT Sensors:** Deploy IoT devices in warehouses and stores to provide real-time visibility into inventory levels, product conditions, and shelf-life data.
#    - **Automated Alerts:** The system generates alerts for low stock levels, overstock situations, or inventory discrepancies, enabling proactive decision-making.
#
# 3. **Autonomous Reordering:**
#    - **Smart Reorder Points:** The AI calculates optimal reorder points and quantities based on predicted demand, safety stock levels, and lead times from suppliers.
#    - **Supplier Integration:** Inbuilt interfaces to connect with suppliers, allowing the AI to place orders automatically when stock levels fall below predetermined thresholds.
#
# 4. **Data Analytics Dashboard:**
#    - **User Interface:** A user-friendly dashboard for inventory managers to visualize inventory status, forecasts, and supplier performance.
#    - **Insights Generation:** The AI generates actionable insights and recommendations, helping managers make informed decisions to optimize inventory and reduce costs.
#
# 5. **Self-Adjustment Mechanism:**
#    - **Agentic Decision-Making:** The AI operates as an autonomous agent, capable of deciding when to place orders or flag issues for human intervention based on predetermined business rules.
#    - **Feedback Loop:** The system refines its decision-making process through a feedback loop that considers the outcomes of past decisions, thus improving its autonomous capabilities over time.
#
# #### Benefits:
#
# - **Cost Reduction:** Minimizes holding and stockout costs through efficient inventory management.
# - **Increased Sales:** Reduces lost sales opportunities by ensuring products are available when customers want them.
# - **Enhanced Efficiency:** Automates repetitive tasks, allowing human employees to focus on strategic activities.
# - **Scalability:** As the business grows, the AI can scale operations without a proportional increase in manual intervention.
#
# #### Implementation Roadmap:
# 1. **Phase 1:** Data Collection & Integration (3 months) - Gather historical sales data and integrate IoT sensors.
# 2. **Phase 2:** Model Development & Testing (6 months) - Develop and validate AI models for demand forecasting and inventory optimization.
# 3. **Phase 3:** Pilot Testing (3 months) - Implement the system in a controlled environment and adjust based on performance metrics.
# 4. **Phase 4:** Full Deployment (3-6 months) - Roll out the system to all locations and provide training for staff.
# 5. **Phase 5:** Continuous Monitoring & Improvement - Regularly review system performance and continuously refine algorithms.
#
# ### Conclusion:
# By implementing this agentic AI-powered inventory optimization system, businesses can successfully navigate the complexities of inventory management, leading to enhanced efficiency, reduced costs, and improved customer satisfaction.
